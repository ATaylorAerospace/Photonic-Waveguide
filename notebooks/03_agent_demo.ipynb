# %% [markdown]
# # Agent Demo
# Interactive demo of the SiN Photonic Waveguide MCP Agent.

# %%
from src.agents.photonic_agent import create_coordinator_agent
agent = create_coordinator_agent()
