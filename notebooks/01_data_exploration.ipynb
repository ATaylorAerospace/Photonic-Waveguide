# %% [markdown]
# # Data Exploration
# Exploratory data analysis on the 90K SiN photonic waveguide dataset.

# %%
import pandas as pd
df = pd.read_csv('../data/SiN_Photonic_Waveguide_Loss_Efficiency.csv')
df.head()
